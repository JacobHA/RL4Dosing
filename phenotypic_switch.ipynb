# %%
import numpy as np
import matplotlib.pyplot as plt
from cell_model_pop_fde import Cell_Population

# %%
model = Cell_Population()
model.initialize()

# %%
model.init_conditions
# Out:
# array([[655],
#        [  0]])

# %% [markdown]
# choose action (antibiotic conc., either 0 or 1), simulate to obtain cost

# %%
b = 0 # antibiotic concentration (action)
t, tot, cost, next_state = model.simulate_population(b, delta_t=5)

# %%
plt.plot(t, tot)
plt.xlabel('time (h)')
plt.ylabel('population size')
plt.show()
print('Cost:',cost)
# Out:
# Cost: 0.1515182614554723

# %% [markdown]
# choosing another action

# %%
b = 1 # antibiotic concentration
t, tot, cost, next_state = model.simulate_population(b, delta_t=5)

# %%
plt.plot(t, tot)
plt.xlabel('time (h)')
plt.ylabel('population size')
plt.show()
print('Cost:',cost)
# Out:
# Cost: 0.06323897114806769

# %%
cost
# Out:
# -0.05745080659087254
